# %% [markdown]
# # 252 데이터 해석의 개념
#
#
# ![스크린샷 2021-10-01 오후 3.05.56.png](attachment:73ac3f0f-9a85-4a93-9a6a-c5c37a02dac6.png)

# %% [markdown]
# # 253 Jupyter notebook

# %% [markdown]
# # 254 numpy

# %% [markdown]
# # 255 pandas
# pip install pandas_datareader

# %% [markdown]
# # 256 matplotlib

# %% [markdown]
# # 257 scikit-learn

# %% [markdown]
# # 258 주가의 데이터 해석과 예측
