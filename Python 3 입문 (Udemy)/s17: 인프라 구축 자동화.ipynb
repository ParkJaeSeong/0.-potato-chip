# %% [markdown]
# ### 209 인프라 자동 구축 환경
#
# ![스크린샷 2021-08-28 오후 9.35.43.png](attachment:5e43248e-fc7e-4b40-83d0-3f01d4b828b0.png)
#
# - ARCH 리눅스 (M1에서는 VirtualBox 설치가 안됨)
# - VirtualBox 설치
# - Vagrant 설치

# %%
# vagrant up # Vagrantfile 설치
# vagrant status # 상태 보기
# vagrant provision main # provision 재실행

# vagrant ssh main (main 접속)
# ubuntu 16.04 python3.5 -> 3.6으로 업그레이드, 그리고 pip3 업그레이드

# vagrant halt (정지)

# %% [markdown]
# # 214 Fabric
#
# https://www.fabfile.org/
