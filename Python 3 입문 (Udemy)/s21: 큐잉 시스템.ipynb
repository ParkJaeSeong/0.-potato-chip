# %% [markdown]
# # 260 쿠잉 시스템 이란
#
# ![스크린샷 2021-10-01 오후 4.05.06.png](attachment:9673da6c-3ff6-44be-8366-7c16eb4b8853.png)

# %% [markdown]
# ## 261 ZeroMQ Push, Pull
# ## 262 ZeroMQ Pub, Sub
#
# https://zeromq.org/

# %%
# Python ZeroMQ binding (pyzmq)

# pip install pyzmq (ZeroMQ)

# %% [markdown]
# # 263 RabbitMQ
#
# https://www.rabbitmq.com/

# %%
# arch -arm64 brew install rabbitmq

# brew services start rabbitmq
# /opt/homebrew/opt/rabbitmq/sbin/rabbitmq-server 
# management plugin http://localhost:15672


# brew services start memcached
# /opt/homebrew/opt/memcached/bin/memcached -l localhost

# %% [markdown]
# # 265 celery

# %%
# pip install celery

# %%
# The cache backend supports the pylibmc and python-memcached libraries. The latter is used only if pylibmc isn’t installed.

# 참조 http://sendapatch.se/projects/pylibmc/install.html#from-pypi
# brew install libmemcached - pylibmc 설치에 필요
# pip install pylibmc --install-option="--with-libmemcached=/opt/homebrew/opt/libmemcached/"
# import error
# pip uninstall pylibmc

# %%
import pylibmc
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-e214ec6b497d> in <module>
# ----> 1 import pylibmc
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pylibmc/__init__.py in <module>
#      69 """
#      70
# ---> 71 import _pylibmc
#      72 from _pylibmc import *
#      73 from _pylibmc import __version__
#
# ImportError: dlopen(/Users/jspark/opt/anaconda3/lib/python3.8/site-packages/_pylibmc.cpython-38-darwin.so, 2): Symbol not found: _memcached_add
#   Referenced from: /Users/jspark/opt/anaconda3/lib/python3.8/site-packages/_pylibmc.cpython-38-darwin.so
#   Expected in: flat namespace
#  in /Users/jspark/opt/anaconda3/lib/python3.8/site-packages/_pylibmc.cpython-38-darwin.so

# %%
# pip install python-memcached

# %%
# celery -A tasker worker -l info  # Tasker 실행
# python 265.py # 비동기 테스트
